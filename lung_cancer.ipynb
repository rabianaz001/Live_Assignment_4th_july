# %% [markdown]
# # 2. Do the EDA on the given dataset: Lung cancer, and extract some useful information from this.
# Dataset Description:
# Lung cancer is one of the _ost prevalent and deadly for_s of cancer worldwide, presenting significant
# challenges in early detection and effective treat_ent. To aid in the global effort to understand and co_bat this
# disease, we are excited to introduce our co_prehensive Lung Cancer Dataset.

# %%
# extract file from zip file 
import zipfile

# %%
with zipfile.ZipFile("lungs_cancer.zip",'r')as zip_ref:
    zip_ref.extractall()

# %%
# read csv file 
import pandas as pd
import numpy as np 
df = pd.read_csv("dataset.csv")
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.head() #to see first five rows and columns
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.tail() # to see last five rows and columns
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 2995         2                    1                      1           2
# ...

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
#to know the duplicate value
df[df.duplicated()]
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1476      M   53        1               2        2              2
# 2039      M   50        1               1        1              2
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 1476                2        1        1         1                  1
# 2039                1        2        1         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 1476         2                    2                      1           2
# 2039         2                    2                      1           2
#
#      LUNG_CANCER
# 1476          NO
# 2039         YES

# %%
#TO check the total no.of duplicate value
df.duplicated().sum()
# Out:
# 2

# %%
# to known the column name
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
# check for missing values
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.nunique() #checking for duplicate values
# Out:
# GENDER                    2
# AGE                      51
# SMOKING                   2
# YELLOW_FINGERS            2
# ANXIETY                   2
# PEER_PRESSURE             2
# CHRONIC_DISEASE           2
# FATIGUE                   2
# ALLERGY                   2
# WHEEZING                  2
# ALCOHOL_CONSUMING         2
# COUGHING                  2
# SHORTNESS_OF_BREATH       2
# SWALLOWING_DIFFICULTY     2
# CHEST_PAIN                2
# LUNG_CANCER               2
# dtype: int64

# %%
#for performing visualization
import seaborn as sns
import matplotlib.pyplot as plt
import warnings as wr
wr.filterwarnings('ignore')

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["AGE"].dropna(), kde=True, color="blue")
plt.title("Distribution of Smoker's Age")
plt.xlabel("Age")
plt.ylabel("SMOKING")
plt.show()

# %%
alcohol_consumer_counts = df['ALCOHOL_CONSUMING'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(alcohol_consumer_counts.index,alcohol_consumer_counts ,color = 'pink')
plt.xlabel('ALCOHOL_CONSUMING')
plt.ylabel('Count')
plt.title("Count plot of ALCOHOL_CONSUMING")
plt.show()

# %%
df[ 'LUNG_CANCER'].value_counts().plot.pie(autopct="%1.1f%%",colors=["lightcoral","lightgreen"],explode=(0,0.1),wedgeprops=dict(width=0.5),startangle=90)
plt.title("How many have lung_cancer")
# Out:
# Text(0.5, 1.0, 'How many have lung_cancer')

# %%
cat_col=[col for col in df.columns if df[col].dtypes=="O"]
num_col=[col for col in df.columns if df[col].dtypes!="O"]

# %%
plt.figure(figsize=(20,15))
plotnumber=1

for col in num_col:
  if plotnumber <= 15:
    ax = plt.subplot(3,5,plotnumber)
    sns.distplot(df[col])
    plt.xlabel(col)
  plotnumber +=1

plt.tight_layout()
plt.show()

# %%
sns.set_palette("Pastel1")
plt.figure(figsize =(10,8))
sns.pairplot(data = df)
plt.suptitle('Pairplot for Data Frame')
plt.show()

# %%
plt.figure(figsize=(16,14))
sns.heatmap(df.corr(),annot =True ,fmt = '2f',cmap = 'Pastel2', linewidths= 2)
plt.title("Correlation Heatmap")
plt.show()

#value close to +1 indicates strong positive correalation,-1 indicates a strong negative correlation and 0 indicates suggests no linear correlation.

# %%
df["ALLERGY"].value_counts().plot.pie(autopct="%1.1f%%",colors=["lightcoral","lightgreen"],explode=(0,0.1),wedgeprops=dict(width=0.5),startangle=90)
# Out:
# <AxesSubplot: ylabel='ALLERGY'>

# %% [markdown]
# # conclusion
#
# The Python_Based exploratory data analysis(EDA) of lung_cancer dataset has yield important new information about the dataset.
# We invetigated correlation between variables,identified outliers,and obtained a knowledge of the distribution of important features using visualization.The quantative and qualitative features of the dataset were analyzed in detail through the use of various plots,including pair,box,count,histogram plot.
